# %%
cd /home/ted/my-github/r4wpy/web-crawling/book-examples/
# Out:
# /home/ted/my-github/r4wpy/web-crawling/book-examples

# %%
# %ls
# Out:
# 4-1.py    4-3.py  4-5.py  5-1.py         data.json   test.py
# 4-2.html  4-4.py  4-6.py  bookspider.py  movies.txt

# %%
# %matplotlib inline
import pandas as pd
data = pd.read_json('data.json', lines=True)

# %%
data
# Out:
#                名称            国家    年份   排名     评价人数   评分
# 0          肖申克的救赎            美国  1995    1  1364077  9.6
# 1            霸王别姬       中国大陆,香港  1993    2  1008366  9.6
# 2         这个杀手不太冷            法国  1994    3  1246719  9.4
# 3            阿甘正传            美国  1994    4  1074578  9.4
# 4            美丽人生           意大利  1997    5   628401  9.5
# 5           泰坦尼克号            美国  1997    6  1014315  9.3
# 6            千与千寻            日本  2001    7  1001257  9.3
# 7          辛德勒的名单            美国  1993    8   560577  9.5
# 8            盗梦空间         美国,英国  2010    9  1084834  9.3
# 9         忠犬八公的故事         美国,英国  2009   10   711311  9.3
# 10         机器人总动员            美国  2008   11   719184  9.3
# 11        三傻大闹宝莱坞            印度  2009   12   971979  9.2
# 12          海上钢琴师           意大利  1998   13   799920  9.2
# 13         放牛班的春天      法国,瑞士,德国  2004   14   671578  9.3
# 14          楚门的世界            美国  1998   15   739627  9.2
# ...

# %%
data.plot(x='年份',y='')
# Out:
#                名称            国家    年份   排名     评价人数   评分
# 0          肖申克的救赎            美国  1995    1  1364077  9.6
# 1            霸王别姬       中国大陆,香港  1993    2  1008366  9.6
# 2         这个杀手不太冷            法国  1994    3  1246719  9.4
# 3            阿甘正传            美国  1994    4  1074578  9.4
# 4            美丽人生           意大利  1997    5   628401  9.5
# 5           泰坦尼克号            美国  1997    6  1014315  9.3
# 6            千与千寻            日本  2001    7  1001257  9.3
# 7          辛德勒的名单            美国  1993    8   560577  9.5
# 8            盗梦空间         美国,英国  2010    9  1084834  9.3
# 9         忠犬八公的故事         美国,英国  2009   10   711311  9.3
# 10         机器人总动员            美国  2008   11   719184  9.3
# 11        三傻大闹宝莱坞            印度  2009   12   971979  9.2
# 12          海上钢琴师           意大利  1998   13   799920  9.2
# 13         放牛班的春天      法国,瑞士,德国  2004   14   671578  9.3
# 14          楚门的世界            美国  1998   15   739627  9.2
# ...

# %%
new = data.groupby(['年份']).size().reset_index(name='count').sort_values(['年份'], ascending=False)

# %%
new.plot(x='年份',y='count')

# %%
new = data['国家'].str.split(',', n=4, expand=True)

# %%
new
# Out:
#         0     1     2     3     4
# 0      美国  None  None  None  None
# 1    中国大陆    香港  None  None  None
# 2      法国  None  None  None  None
# 3      美国  None  None  None  None
# 4     意大利  None  None  None  None
# 5      美国  None  None  None  None
# 6      日本  None  None  None  None
# 7      美国  None  None  None  None
# 8      美国    英国  None  None  None
# 9      美国    英国  None  None  None
# 10     美国  None  None  None  None
# 11     印度  None  None  None  None
# 12    意大利  None  None  None  None
# 13     法国    瑞士    德国  None  None
# 14     美国  None  None  None  None
# 15     香港  中国大陆  None  None  None
# 16     美国    英国   加拿大    冰岛  None
# 17     日本  None  None  None  None
# 18     美国  None  None  None  None
# 19     韩国  None  None  None  None
# 20     香港  None  None  None  None
# 21     美国  None  None  None  None
# 22     美国  None  None  None  None
# 23     美国  None  None  None  None
# 24     法国  None  None  None  None
# 25     美国  None  None  None  None
# ...
